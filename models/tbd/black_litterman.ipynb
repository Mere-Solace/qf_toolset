# %% [markdown]
# # Black-Litterman
#
# Combines a prior (e.g., market-implied forward rates) with your views (e.g., "10Y overvalued by 30bps"). Solves the instability problem of raw Markowitz. Well-suited when you have a macro thesis but don't want it to dominate completely.

# %%
# TODO
