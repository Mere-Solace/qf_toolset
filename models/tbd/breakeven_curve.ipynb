# %% [markdown]
# # Breakeven Curve Analysis
#
# 5Y vs. 10Y breakeven spread + 5Y5Y forward tracks where markets expect inflation to settle. Useful for the TIPS vs. nominal allocation decision.

# %%
# TODO
