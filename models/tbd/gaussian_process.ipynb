# %% [markdown]
# # Gaussian Process Regression
#
# Non-parametric curve fitting with uncertainty quantification. Gives you a full posterior distribution over the yield curve shape, not just a fitted line.

# %%
# TODO
