# %% [markdown]
# # Nelson-Siegel / Svensson
#
# Parametric curve fitting with interpretable factors (β₀ = long-run level, β₁ = slope, β₂ = curvature). Lets you fit the curve, interpolate missing tenors, and track factor evolution over time.

# %%
# TODO
