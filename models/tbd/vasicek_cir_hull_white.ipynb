# %% [markdown]
# # Vasicek / CIR / Hull-White
#
# Short-rate models for simulating future rate paths. Hull-White fits the current curve exactly (good for scenario pricing). CIR enforces non-negative rates. Feed outputs into Monte Carlo for DV01/convexity stress tests.

# %%
# TODO
