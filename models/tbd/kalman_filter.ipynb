# %% [markdown]
# # Kalman Filter (State-Space)
#
# Ideal for estimating unobservables: r* (neutral real rate), the Fed's latent policy path, or the "cycle" component of yields. The Fed itself uses variants of this.

# %%
# TODO
