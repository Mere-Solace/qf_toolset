# %% [markdown]
# # Markov-Switching VAR
#
# Like HMM but the transition dynamics and covariance structure shift between regimes. Captures that rates and spreads behave differently in stress vs. normal periods.

# %%
# TODO
