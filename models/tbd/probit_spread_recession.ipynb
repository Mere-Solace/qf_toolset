# %% [markdown]
# # Probit / Logistic on Spread Inversions
#
# The literature gold standard (Estrella & Mishkin). T10Y3M → recession probability 12 months ahead. `RECPROUSM156N` and `SAHMREALTIME` serve as targets or benchmarks.

# %%
# TODO
