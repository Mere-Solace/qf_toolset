# %% [markdown]
# # Mean-Variance (Markowitz) on Duration Buckets
#
# Treat each tenor bucket (0–2Y, 2–5Y, 5–10Y, 10–30Y) as an asset. Use rolling covariance of returns. Classic but sensitive to inputs.

# %%
# TODO
