# %% [markdown]
# # Granger Causality Network
#
# Build a directed graph: does T10Y2Y Granger-cause VIX? Does NFCI lead rates? Identifies which macro series are leading vs. lagging in your specific dataset.

# %%
# TODO
