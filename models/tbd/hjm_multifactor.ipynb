# %% [markdown]
# # Multi-Factor HJM
#
# Simulate the full forward curve jointly (Heath-Jarrow-Morton framework). More realistic for butterfly/curve trades than single-factor short-rate models. Computationally heavier but captures curve shape dynamics.

# %%
# TODO
