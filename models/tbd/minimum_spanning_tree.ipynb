# %% [markdown]
# # Minimum Spanning Tree on Rate Correlations
#
# Useful for visualizing which tenors/macro variables cluster together and spotting regime breaks (the tree topology changes during stress periods).

# %%
# TODO
