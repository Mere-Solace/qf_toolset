# %% [markdown]
# # Gradient Boosted Trees — Recession Classification
#
# Use all macro series as features → predict `USREC` (or recession probability) with XGBoost / LightGBM. Gives feature importances and handles nonlinear interactions the probit misses. Needs careful walk-forward validation.

# %%
# TODO
